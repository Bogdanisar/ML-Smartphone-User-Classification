# %%
#!//usr/bin/python3.6

import numpy as np
from sklearn import preprocessing

splitNum = 450
numBins = 2
bins = np.linspace(0, 1, numBins + 1)
idToData = {}
scaler = None

def loadTrainLabels(path):
	pairs = np.loadtxt(path, delimiter=',', skiprows=1, dtype=int)
	# print(pairs) #############

	mp = {}
	for p in pairs:
		mp[p[0]] = p[1]

	return pairs[:, 0], pairs, mp

def sortData():
	# print(idLabelPairs[idLabelPairs[:, 1] == 7])

	idsOfUser = np.zeros((21, 450), dtype=int)
	for u in range(1, 21):
		idsOfUser[u, :] = idLabelPairs[ idLabelPairs[:, 1] == u, 0]

	return idsOfUser

def splitData():
	trainArrays = []
	validationArrays = []

	for u in range(1, 21):
		trainArrays.append( idsOfUser[u, 0:splitNum] )
		validationArrays.append( idsOfUser[u, splitNum:] )

	trainId = np.concatenate(tuple(trainArrays), axis=0)
	validationId = np.concatenate(tuple(validationArrays), axis=0)
	return trainId, validationId

def loadData(path, ids):
	count = 0
	for id in ids:
		count += 1
		idToData[id] = np.loadtxt(path + str(id) + ".csv", delimiter=',', skiprows=0, dtype=np.float64)

		##################################
		if (count % 100 == 0):
			print("loaded", count, "data")
			# print(idToData[id]) 
			print("=" * 20, "\n")

def fitScaler():
	# xArrays = []
	# yArrays = []
	# zArrays = []
	# for id in trainId:
	# 	array = idToData[id]
	# 	xArrays.append(array[:, 0])
	# 	yArrays.append(array[:, 1])
	# 	zArrays.append(array[:, 2])

	# xValues = np.concatenate(tuple(xArrays), axis=0)
	# yValues = np.concatenate(tuple(yArrays), axis=0)
	# zValues = np.concatenate(tuple(zArrays), axis=0)

	# print(xValues) ###########


	# xScaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
	# xScaler.fit(xValues.reshape())

	# yScaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
	# yScaler.fit(yValues)

	# zScaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
	# zScaler.fit(zValues)

	# for array in idToData.values():
	# 	xScaler.fit(array[:, 0])
	# 	yScaler.fit(array[:, 1])
	# 	zScaler.fit(array[:, 2])


	arrays = []
	for id in trainId:
		arrays.append(idToData[id])

	values = np.concatenate(tuple(arrays), axis=0)

	global scaler
	scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
	scaler.fit(values)


	print("Fitted the scaler")


def normalizeMinMax(ids):
	for id in ids:
		idToData[id] = scaler.transform(idToData[id])

	print("Normalized data")

def interpolateData(ids):
	for id in ids:
		array = idToData[id]
		newArray = np.zeros((150, 3))

		x = np.arange(1, 151, 1)	
		xp = np.linspace(1, 150, array.shape[0])
		for k in range(0, 3):
			yp = array[:, k]
			newArray[:, k] = np.interp(x, xp, yp)

		idToData[id] = newArray

	print("interpolized data")


def computeProbabilityMatrix():
	probMatrix = np.zeros((150, numBins ** 3, 21))

	for userIndex in range(1, 21):
		resultBins = np.zeros(idsOfUser[userIndex].size, dtype=int)
		for featureIndex in range(150):

			for i in range(idsOfUser[userIndex].size):
				id = idsOfUser[userIndex][i]
				data = idToData[id]
				resultBins[i] = pointToBin(data[featureIndex, :])

			for binIndex in range(numBins ** 3):
				probMatrix[featureIndex][binIndex][userIndex] = np.sum(resultBins == binIndex) / (resultBins.size)

	print("computed probability matrix")
	return probMatrix





allTrainId, idLabelPairs, idToLabel = loadTrainLabels("../../data/train_labels.csv")
# print(allTrainId) #################
# print(idToLabel)



# test PointToBin
# print(bins)
# test = np.array([[0.3, 0.6]] * 3)
# print(test)
# for i in range(test.shape[1]):
# 	for j in range(test.shape[1]):
# 		for k in range(test.shape[1]):
# 			point = np.array((test[0, i], test[1, j], test[2, k]))
# 			print(point, pointToBin(point))




idsOfUser = sortData()
# print(idsOfUser)
# print('=' * 20)

trainId, validationId = splitData()
###########################################################################
# print(trainId.size)
# print(validationId.size)
# print("=" * 20)
# print(trainId)
# print(validationId)


loadData("../../data/train/", allTrainId)
# print(idToData) ##################
# print(list(idToData.values()))


fitScaler()
normalizeMinMax(np.concatenate((trainId, validationId)))
interpolateData(np.concatenate((trainId, validationId)))


# print("normalizedData of 23999:") ###########
# print(idToData[23999])



probMatrix = computeProbabilityMatrix()
# Out:
# loaded 100 data
# ====================
#
# loaded 200 data
# ====================
#
# loaded 300 data
# ====================
#
# loaded 400 data
# ====================
#
# loaded 500 data
# ====================
#
# loaded 600 data
# ====================
#
# loaded 700 data
# ====================
#
# loaded 800 data
# ====================
#
# loaded 900 data
# ====================
#
# loaded 1000 data
# ====================
#
# loaded 1100 data
# ====================
#
# loaded 1200 data
# ====================
#
# loaded 1300 data
# ====================
#
# loaded 1400 data
# ====================
#
# loaded 1500 data
# ====================
#
# loaded 1600 data
# ====================
#
# loaded 1700 data
# ====================
#
# loaded 1800 data
# ====================
#
# loaded 1900 data
# ====================
#
# loaded 2000 data
# ====================
#
# loaded 2100 data
# ====================
#
# loaded 2200 data
# ====================
#
# loaded 2300 data
# ====================
#
# loaded 2400 data
# ====================
#
# loaded 2500 data
# ====================
#
# loaded 2600 data
# ====================
#
# loaded 2700 data
# ====================
#
# loaded 2800 data
# ====================
#
# loaded 2900 data
# ====================
#
# loaded 3000 data
# ====================
#
# loaded 3100 data
# ====================
#
# loaded 3200 data
# ====================
#
# loaded 3300 data
# ====================
#
# loaded 3400 data
# ====================
#
# loaded 3500 data
# ====================
#
# loaded 3600 data
# ====================
#
# loaded 3700 data
# ====================
#
# loaded 3800 data
# ====================
#
# loaded 3900 data
# ====================
#
# loaded 4000 data
# ====================
#
# loaded 4100 data
# ====================
#
# loaded 4200 data
# ====================
#
# loaded 4300 data
# ====================
#
# loaded 4400 data
# ====================
#
# loaded 4500 data
# ====================
#
# loaded 4600 data
# ====================
#
# loaded 4700 data
# ====================
#
# loaded 4800 data
# ====================
#
# loaded 4900 data
# ====================
#
# loaded 5000 data
# ====================
#
# loaded 5100 data
# ====================
#
# loaded 5200 data
# ====================
#
# loaded 5300 data
# ====================
#
# loaded 5400 data
# ====================
#
# loaded 5500 data
# ====================
#
# loaded 5600 data
# ====================
#
# loaded 5700 data
# ====================
#
# loaded 5800 data
# ====================
#
# loaded 5900 data
# ====================
#
# loaded 6000 data
# ====================
#
# loaded 6100 data
# ====================
#
# loaded 6200 data
# ====================
#
# loaded 6300 data
# ====================
#
# loaded 6400 data
# ====================
#
# loaded 6500 data
# ====================
#
# loaded 6600 data
# ====================
#
# loaded 6700 data
# ====================
#
# loaded 6800 data
# ====================
#
# loaded 6900 data
# ====================
#
# loaded 7000 data
# ====================
#
# loaded 7100 data
# ====================
#
# loaded 7200 data
# ====================
#
# loaded 7300 data
# ====================
#
# loaded 7400 data
# ====================
#
# loaded 7500 data
# ====================
#
# loaded 7600 data
# ====================
#
# loaded 7700 data
# ====================
#
# loaded 7800 data
# ====================
#
# loaded 7900 data
# ====================
#
# loaded 8000 data
# ====================
#
# loaded 8100 data
# ====================
#
# loaded 8200 data
# ====================
#
# loaded 8300 data
# ====================
#
# loaded 8400 data
# ====================
#
# loaded 8500 data
# ====================
#
# loaded 8600 data
# ====================
#
# loaded 8700 data
# ====================
#
# loaded 8800 data
# ====================
#
# loaded 8900 data
# ====================
#
# loaded 9000 data
# ====================
#
# Fitted the scaler
# Normalized data
# interpolized data
# computed probability matrix

# %%
def computeLabels(ids):
    result = np.zeros((ids.shape[0], 21))

    for i in range(ids.shape[0]):
        id = ids[i]
        data = idToData[id]

        for user in range(1, 21):

            prob = 0
            for featureIndex in range(150):
                point = data[featureIndex, :]

    # 				print("point,binOfPoint = ", point, ", ", pointToBin(point))

                prob += np.log(probMatrix[featureIndex, pointToBin(point), user] + 1e-3)

            result[i, user] = prob

        print("computed result for", id, "; i = ", i)
        print(" class is: ", np.argmax(result[i, 1:]) + 1)

    return np.argmax(result[:, 1:], axis = 1) + 1

def getAccuracy(actual, predicted):
    return np.sum(actual == predicted).sum() / actual.shape[0] * 100



def doValidation():
    predictedLabels = computeLabels(validationId)
    print("predicted label - id")
    print(validationId)
    print(predictedLabels)


    actualLabels = np.zeros(validationId.shape[0])
    for i in range(validationId.shape[0]):
        actualLabels[i] = idToLabel[validationId[i]]

    accuracy = getAccuracy(actualLabels, predictedLabels)
    print("accuracy =", accuracy)

def getLabelsFor(ids):
    predictedLabels = computeLabels(ids)
    return predictedLabels


def pointToBin(point):
    for k in range(3):
        point[k] = min(0.99999999999, point[k])
        point[k] = max(0.0, point[k])
    
    index = np.digitize(point, bins) - 1

    ans = 0
    for k in range(point.size):
        ans += index[k] * numBins ** (point.size - k - 1)

    return ans

# doValidation()



testId = np.loadtxt("../test_files.txt", dtype=int)

# testId = np.array(list(map(lambda x: testId[x], [947, 948, 949, 950]))) ########### WATCH ME #################
# testId = testId[0 : (int)(0.2 * testId.size)] ################################## WATCH ME ######################
# print("testId ndarray", testId, "; size = ", testId.shape)

loadData("../../data/test/", testId)
normalizeMinMax(testId)
interpolateData(testId)


# i = 948
# print("i = ", i, "testId[i] = ", testId[i])
# print(idToData[testId[i]])


testLabels = getLabelsFor(testId)
print(np.stack((testId, testLabels), axis = 1))

np.savetxt("result.csv", np.stack((testId, testLabels)).T, fmt="%s", delimiter=',', header="id,class", comments='')
# Out:
# loaded 100 data
# ====================
#
# loaded 200 data
# ====================
#
# loaded 300 data
# ====================
#
# loaded 400 data
# ====================
#
# loaded 500 data
# ====================
#
# loaded 600 data
# ====================
#
# loaded 700 data
# ====================
#
# loaded 800 data
# ====================
#
# loaded 900 data
# ====================
#
# loaded 1000 data
# ====================
#
# loaded 1100 data
# ====================
#
# loaded 1200 data
# ====================
#
# loaded 1300 data
# ====================
#
# loaded 1400 data
# ====================
#
# loaded 1500 data
# ====================
#
# loaded 1600 data
# ====================
#
# loaded 1700 data
# ====================
#
# loaded 1800 data
# ====================
#
# loaded 1900 data
# ====================
#
# loaded 2000 data
# ====================
#
# loaded 2100 data
# ====================
#
# loaded 2200 data
# ====================
#
# loaded 2300 data
# ====================
#
# loaded 2400 data
# ====================
#
# loaded 2500 data
# ====================
#
# loaded 2600 data
# ====================
#
# loaded 2700 data
# ====================
#
# loaded 2800 data
# ====================
#
# loaded 2900 data
# ====================
#
# loaded 3000 data
# ====================
#
# loaded 3100 data
# ====================
#
# loaded 3200 data
# ====================
#
# loaded 3300 data
# ====================
#
# loaded 3400 data
# ====================
#
# loaded 3500 data
# ====================
#
# loaded 3600 data
# ====================
#
# loaded 3700 data
# ====================
#
# loaded 3800 data
# ====================
#
# loaded 3900 data
# ====================
#
# loaded 4000 data
# ====================
#
# loaded 4100 data
# ====================
#
# loaded 4200 data
# ====================
#
# loaded 4300 data
# ====================
#
# loaded 4400 data
# ====================
#
# loaded 4500 data
# ====================
#
# loaded 4600 data
# ====================
#
# loaded 4700 data
# ====================
#
# loaded 4800 data
# ====================
#
# loaded 4900 data
# ====================
#
# loaded 5000 data
# ====================
#
# Normalized data
# interpolized data
# computed result for 10001 ; i =  0
#  class is:  3
# computed result for 10002 ; i =  1
#  class is:  6
# computed result for 10004 ; i =  2
#  class is:  9
# computed result for 10008 ; i =  3
#  class is:  18
# computed result for 10009 ; i =  4
#  class is:  4
# computed result for 10010 ; i =  5
#  class is:  20
# computed result for 10011 ; i =  6
#  class is:  9
# computed result for 10015 ; i =  7
#  class is:  4
# computed result for 10023 ; i =  8
#  class is:  5
# computed result for 10027 ; i =  9
#  class is:  3
# computed result for 10032 ; i =  10
#  class is:  18
# computed result for 10034 ; i =  11
#  class is:  5
# computed result for 10035 ; i =  12
#  class is:  15
# computed result for 10040 ; i =  13
#  class is:  20
# computed result for 10041 ; i =  14
#  class is:  17
# computed result for 10043 ; i =  15
#  class is:  6
# computed result for 10044 ; i =  16
#  class is:  19
# computed result for 10045 ; i =  17
#  class is:  9
# computed result for 10048 ; i =  18
#  class is:  7
# computed result for 10051 ; i =  19
#  class is:  18
# computed result for 10057 ; i =  20
#  class is:  17
# computed result for 10060 ; i =  21
#  class is:  18
# computed result for 10061 ; i =  22
#  class is:  12
# computed result for 10063 ; i =  23
#  class is:  4
# computed result for 10068 ; i =  24
#  class is:  16
# computed result for 10069 ; i =  25
#  class is:  18
# computed result for 10073 ; i =  26
#  class is:  14
# computed result for 10080 ; i =  27
#  class is:  2
# computed result for 10083 ; i =  28
#  class is:  18
# computed result for 10084 ; i =  29
#  class is:  3
# computed result for 10089 ; i =  30
#  class is:  18
# computed result for 10093 ; i =  31
#  class is:  6
# computed result for 10095 ; i =  32
#  class is:  10
# computed result for 10097 ; i =  33
#  class is:  9
# computed result for 10099 ; i =  34
#  class is:  4
# computed result for 10102 ; i =  35
#  class is:  3
# computed result for 10104 ; i =  36
#  class is:  6
# computed result for 10105 ; i =  37
#  class is:  14
# computed result for 10107 ; i =  38
#  class is:  3
# computed result for 10115 ; i =  39
#  class is:  1
# computed result for 10116 ; i =  40
#  class is:  5
# computed result for 10118 ; i =  41
#  class is:  4
# computed result for 10123 ; i =  42
#  class is:  3
# computed result for 10126 ; i =  43
#  class is:  13
# computed result for 10127 ; i =  44
#  class is:  19
# computed result for 10129 ; i =  45
#  class is:  3
# computed result for 10130 ; i =  46
#  class is:  8
# computed result for 10131 ; i =  47
#  class is:  20
# computed result for 10134 ; i =  48
#  class is:  4
# computed result for 10136 ; i =  49
#  class is:  20
# computed result for 10137 ; i =  50
#  class is:  17
# computed result for 10139 ; i =  51
#  class is:  13
# computed result for 10141 ; i =  52
#  class is:  4
# computed result for 10147 ; i =  53
#  class is:  2
# computed result for 10148 ; i =  54
#  class is:  13
# computed result for 10149 ; i =  55
#  class is:  12
# computed result for 10151 ; i =  56
#  class is:  11
# computed result for 10152 ; i =  57
#  class is:  18
# computed result for 10156 ; i =  58
#  class is:  11
# computed result for 10157 ; i =  59
#  class is:  17
# computed result for 10158 ; i =  60
#  class is:  15
# computed result for 10160 ; i =  61
#  class is:  7
# computed result for 10162 ; i =  62
#  class is:  17
# computed result for 10167 ; i =  63
#  class is:  13
# computed result for 10171 ; i =  64
#  class is:  9
# computed result for 10175 ; i =  65
#  class is:  13
# computed result for 10177 ; i =  66
#  class is:  14
# computed result for 10180 ; i =  67
#  class is:  8
# computed result for 10182 ; i =  68
#  class is:  2
# computed result for 10184 ; i =  69
#  class is:  2
# computed result for 10190 ; i =  70
#  class is:  14
# computed result for 10194 ; i =  71
#  class is:  8
# computed result for 10195 ; i =  72
#  class is:  11
# computed result for 10197 ; i =  73
#  class is:  5
# computed result for 10198 ; i =  74
#  class is:  12
# computed result for 10202 ; i =  75
#  class is:  11
# computed result for 10203 ; i =  76
#  class is:  5
# computed result for 10204 ; i =  77
#  class is:  11
# computed result for 10209 ; i =  78
#  class is:  16
# computed result for 10210 ; i =  79
#  class is:  9
# computed result for 10223 ; i =  80
#  class is:  17
# computed result for 10226 ; i =  81
#  class is:  5
# computed result for 10232 ; i =  82
#  class is:  17
# computed result for 10235 ; i =  83
#  class is:  11
# computed result for 10236 ; i =  84
#  class is:  11
# computed result for 10237 ; i =  85
#  class is:  12
# computed result for 10241 ; i =  86
#  class is:  19
# computed result for 10242 ; i =  87
#  class is:  12
# computed result for 10244 ; i =  88
#  class is:  20
# computed result for 10246 ; i =  89
#  class is:  17
# computed result for 10247 ; i =  90
#  class is:  17
# computed result for 10248 ; i =  91
#  class is:  16
# computed result for 10250 ; i =  92
#  class is:  11
# computed result for 10251 ; i =  93
#  class is:  9
# computed result for 10256 ; i =  94
#  class is:  11
# computed result for 10259 ; i =  95
#  class is:  1
# computed result for 10260 ; i =  96
#  class is:  4
# computed result for 10261 ; i =  97
#  class is:  9
# computed result for 10263 ; i =  98
#  class is:  19
# computed result for 10264 ; i =  99
#  class is:  8
# computed result for 10265 ; i =  100
#  class is:  5
# computed result for 10267 ; i =  101
#  class is:  18
# computed result for 10269 ; i =  102
#  class is:  17
# computed result for 10273 ; i =  103
#  class is:  11
# computed result for 10276 ; i =  104
#  class is:  14
# computed result for 10285 ; i =  105
#  class is:  17
# computed result for 10287 ; i =  106
#  class is:  13
# computed result for 10291 ; i =  107
#  class is:  17
# computed result for 10296 ; i =  108
#  class is:  10
# computed result for 10300 ; i =  109
#  class is:  3
# computed result for 10301 ; i =  110
#  class is:  17
# computed result for 10304 ; i =  111
#  class is:  9
# computed result for 10305 ; i =  112
#  class is:  2
# computed result for 10309 ; i =  113
#  class is:  11
# computed result for 10310 ; i =  114
#  class is:  1
# computed result for 10320 ; i =  115
#  class is:  20
# computed result for 10322 ; i =  116
#  class is:  12
# computed result for 10323 ; i =  117
#  class is:  3
# computed result for 10324 ; i =  118
#  class is:  11
# computed result for 10325 ; i =  119
#  class is:  4
# computed result for 10329 ; i =  120
#  class is:  9
# computed result for 10336 ; i =  121
#  class is:  14
# computed result for 10337 ; i =  122
#  class is:  20
# computed result for 10338 ; i =  123
#  class is:  2
# computed result for 10341 ; i =  124
#  class is:  9
# computed result for 10351 ; i =  125
#  class is:  20
# computed result for 10352 ; i =  126
#  class is:  8
# computed result for 10354 ; i =  127
#  class is:  16
# computed result for 10357 ; i =  128
#  class is:  17
# computed result for 10358 ; i =  129
#  class is:  17
# computed result for 10359 ; i =  130
#  class is:  8
# computed result for 10361 ; i =  131
#  class is:  19
# computed result for 10364 ; i =  132
#  class is:  12
# computed result for 10366 ; i =  133
#  class is:  14
# computed result for 10369 ; i =  134
#  class is:  2
# computed result for 10370 ; i =  135
#  class is:  7
# computed result for 10374 ; i =  136
#  class is:  2
# computed result for 10375 ; i =  137
#  class is:  9
# computed result for 10377 ; i =  138
#  class is:  11
# computed result for 10381 ; i =  139
#  class is:  18
# computed result for 10382 ; i =  140
#  class is:  8
# computed result for 10384 ; i =  141
#  class is:  2
# computed result for 10389 ; i =  142
#  class is:  10
# computed result for 10390 ; i =  143
#  class is:  17
# computed result for 10392 ; i =  144
#  class is:  9
# computed result for 10394 ; i =  145
#  class is:  12
# computed result for 10402 ; i =  146
#  class is:  2
# computed result for 10404 ; i =  147
#  class is:  4
# computed result for 10406 ; i =  148
#  class is:  17
# computed result for 10409 ; i =  149
#  class is:  4
# computed result for 10410 ; i =  150
#  class is:  6
# computed result for 10412 ; i =  151
#  class is:  20
# computed result for 10414 ; i =  152
#  class is:  18
# computed result for 10417 ; i =  153
#  class is:  10
# computed result for 10418 ; i =  154
#  class is:  14
# computed result for 10420 ; i =  155
#  class is:  20
# computed result for 10423 ; i =  156
#  class is:  10
# computed result for 10426 ; i =  157
#  class is:  9
# computed result for 10427 ; i =  158
#  class is:  4
# computed result for 10434 ; i =  159
#  class is:  20
# computed result for 10435 ; i =  160
#  class is:  18
# computed result for 10441 ; i =  161
#  class is:  18
# computed result for 10452 ; i =  162
#  class is:  12
# computed result for 10453 ; i =  163
#  class is:  3
# computed result for 10461 ; i =  164
#  class is:  13
# computed result for 10462 ; i =  165
#  class is:  1
# computed result for 10466 ; i =  166
#  class is:  17
# computed result for 10467 ; i =  167
#  class is:  4
# computed result for 10468 ; i =  168
#  class is:  3
# computed result for 10472 ; i =  169
#  class is:  10
# computed result for 10476 ; i =  170
#  class is:  17
# computed result for 10480 ; i =  171
#  class is:  18
# computed result for 10484 ; i =  172
#  class is:  12
# computed result for 10485 ; i =  173
#  class is:  2
# computed result for 10488 ; i =  174
#  class is:  12
# computed result for 10489 ; i =  175
#  class is:  1
# computed result for 10493 ; i =  176
#  class is:  4
# computed result for 10494 ; i =  177
#  class is:  6
# computed result for 10497 ; i =  178
#  class is:  20
# computed result for 10498 ; i =  179
#  class is:  20
# computed result for 10500 ; i =  180
#  class is:  1
# computed result for 10507 ; i =  181
#  class is:  13
# computed result for 10511 ; i =  182
#  class is:  9
# computed result for 10519 ; i =  183
#  class is:  19
# computed result for 10521 ; i =  184
#  class is:  14
# computed result for 10524 ; i =  185
#  class is:  15
# computed result for 10526 ; i =  186
#  class is:  1
# computed result for 10530 ; i =  187
#  class is:  17
# computed result for 10535 ; i =  188
#  class is:  10
# computed result for 10536 ; i =  189
#  class is:  17
# computed result for 10538 ; i =  190
#  class is:  16
# computed result for 10539 ; i =  191
#  class is:  15
# computed result for 10552 ; i =  192
#  class is:  20
# computed result for 10554 ; i =  193
#  class is:  14
# computed result for 10556 ; i =  194
#  class is:  18
# computed result for 10558 ; i =  195
#  class is:  18
# computed result for 10560 ; i =  196
#  class is:  13
# computed result for 10564 ; i =  197
#  class is:  9
# computed result for 10566 ; i =  198
#  class is:  14
# computed result for 10569 ; i =  199
#  class is:  17
# computed result for 10570 ; i =  200
#  class is:  17
# computed result for 10571 ; i =  201
#  class is:  17
# computed result for 10575 ; i =  202
#  class is:  20
# computed result for 10577 ; i =  203
#  class is:  10
# computed result for 10583 ; i =  204
#  class is:  20
# computed result for 10584 ; i =  205
#  class is:  14
# computed result for 10585 ; i =  206
#  class is:  4
# computed result for 10589 ; i =  207
#  class is:  14
# computed result for 10592 ; i =  208
#  class is:  20
# computed result for 10594 ; i =  209
#  class is:  17
# computed result for 10595 ; i =  210
#  class is:  17
# computed result for 10596 ; i =  211
#  class is:  18
# computed result for 10601 ; i =  212
#  class is:  9
# computed result for 10606 ; i =  213
#  class is:  17
# computed result for 10607 ; i =  214
#  class is:  18
# computed result for 10613 ; i =  215
#  class is:  20
# computed result for 10615 ; i =  216
#  class is:  20
# computed result for 10618 ; i =  217
#  class is:  9
# computed result for 10621 ; i =  218
#  class is:  9
# computed result for 10626 ; i =  219
#  class is:  18
# computed result for 10628 ; i =  220
#  class is:  15
# computed result for 10629 ; i =  221
#  class is:  18
# computed result for 10633 ; i =  222
#  class is:  20
# computed result for 10634 ; i =  223
#  class is:  13
# computed result for 10638 ; i =  224
#  class is:  5
# computed result for 10642 ; i =  225
#  class is:  14
# computed result for 10643 ; i =  226
#  class is:  17
# computed result for 10644 ; i =  227
#  class is:  5
# computed result for 10646 ; i =  228
#  class is:  17
# computed result for 10647 ; i =  229
#  class is:  6
# computed result for 10653 ; i =  230
#  class is:  17
# computed result for 10655 ; i =  231
#  class is:  9
# computed result for 10656 ; i =  232
#  class is:  18
# computed result for 10657 ; i =  233
#  class is:  9
# computed result for 10666 ; i =  234
#  class is:  6
# computed result for 10668 ; i =  235
#  class is:  16
# computed result for 10669 ; i =  236
#  class is:  18
# computed result for 10670 ; i =  237
#  class is:  13
# computed result for 10671 ; i =  238
#  class is:  4
# computed result for 10676 ; i =  239
#  class is:  7
# computed result for 10679 ; i =  240
#  class is:  12
# computed result for 10682 ; i =  241
#  class is:  8
# computed result for 10684 ; i =  242
#  class is:  12
# computed result for 10685 ; i =  243
#  class is:  11
# computed result for 10686 ; i =  244
#  class is:  17
# computed result for 10687 ; i =  245
#  class is:  1
# computed result for 10688 ; i =  246
#  class is:  14
# computed result for 10691 ; i =  247
#  class is:  9
# computed result for 10693 ; i =  248
#  class is:  7
# computed result for 10700 ; i =  249
#  class is:  6
# computed result for 10704 ; i =  250
#  class is:  13
# computed result for 10705 ; i =  251
#  class is:  9
# computed result for 10707 ; i =  252
#  class is:  8
# computed result for 10711 ; i =  253
#  class is:  17
# computed result for 10716 ; i =  254
#  class is:  4
# computed result for 10717 ; i =  255
#  class is:  15
# computed result for 10718 ; i =  256
#  class is:  9
# computed result for 10719 ; i =  257
#  class is:  3
# computed result for 10725 ; i =  258
#  class is:  12
# computed result for 10729 ; i =  259
#  class is:  17
# computed result for 10730 ; i =  260
#  class is:  4
# computed result for 10732 ; i =  261
#  class is:  12
# computed result for 10736 ; i =  262
#  class is:  17
# computed result for 10737 ; i =  263
#  class is:  2
# computed result for 10738 ; i =  264
#  class is:  3
# computed result for 10739 ; i =  265
#  class is:  8
# computed result for 10744 ; i =  266
#  class is:  14
# computed result for 10749 ; i =  267
#  class is:  5
# computed result for 10750 ; i =  268
#  class is:  11
# computed result for 10751 ; i =  269
#  class is:  13
# computed result for 10753 ; i =  270
#  class is:  13
# computed result for 10755 ; i =  271
#  class is:  4
# computed result for 10756 ; i =  272
#  class is:  20
# computed result for 10757 ; i =  273
#  class is:  2
# computed result for 10759 ; i =  274
#  class is:  1
# computed result for 10760 ; i =  275
#  class is:  19
# computed result for 10761 ; i =  276
#  class is:  13
# computed result for 10763 ; i =  277
#  class is:  11
# computed result for 10767 ; i =  278
#  class is:  8
# computed result for 10768 ; i =  279
#  class is:  20
# computed result for 10770 ; i =  280
#  class is:  6
# computed result for 10772 ; i =  281
#  class is:  16
# computed result for 10774 ; i =  282
#  class is:  2
# computed result for 10776 ; i =  283
#  class is:  10
# computed result for 10777 ; i =  284
#  class is:  10
# computed result for 10778 ; i =  285
#  class is:  16
# computed result for 10779 ; i =  286
#  class is:  20
# computed result for 10783 ; i =  287
#  class is:  13
# computed result for 10784 ; i =  288
#  class is:  18
# computed result for 10786 ; i =  289
#  class is:  20
# computed result for 10795 ; i =  290
#  class is:  2
# computed result for 10798 ; i =  291
#  class is:  11
# computed result for 10803 ; i =  292
#  class is:  4
# computed result for 10806 ; i =  293
#  class is:  6
# computed result for 10807 ; i =  294
#  class is:  16
# computed result for 10812 ; i =  295
#  class is:  14
# computed result for 10814 ; i =  296
#  class is:  18
# computed result for 10816 ; i =  297
#  class is:  19
# computed result for 10819 ; i =  298
#  class is:  18
# computed result for 10821 ; i =  299
#  class is:  9
# computed result for 10825 ; i =  300
#  class is:  20
# computed result for 10827 ; i =  301
#  class is:  14
# computed result for 10832 ; i =  302
#  class is:  17
# computed result for 10833 ; i =  303
#  class is:  17
# computed result for 10837 ; i =  304
#  class is:  15
# computed result for 10838 ; i =  305
#  class is:  9
# computed result for 10839 ; i =  306
#  class is:  20
# computed result for 10840 ; i =  307
#  class is:  16
# computed result for 10842 ; i =  308
#  class is:  12
# computed result for 10847 ; i =  309
#  class is:  5
# computed result for 10852 ; i =  310
#  class is:  14
# computed result for 10854 ; i =  311
#  class is:  1
# computed result for 10856 ; i =  312
#  class is:  15
# computed result for 10859 ; i =  313
#  class is:  17
# computed result for 10861 ; i =  314
#  class is:  12
# computed result for 10862 ; i =  315
#  class is:  17
# computed result for 10863 ; i =  316
#  class is:  4
# computed result for 10865 ; i =  317
#  class is:  6
# computed result for 10866 ; i =  318
#  class is:  18
# computed result for 10868 ; i =  319
#  class is:  14
# computed result for 10870 ; i =  320
#  class is:  19
# computed result for 10873 ; i =  321
#  class is:  11
# computed result for 10874 ; i =  322
#  class is:  19
# computed result for 10875 ; i =  323
#  class is:  17
# computed result for 10881 ; i =  324
#  class is:  19
# computed result for 10883 ; i =  325
#  class is:  12
# computed result for 10885 ; i =  326
#  class is:  4
# computed result for 10886 ; i =  327
#  class is:  10
# computed result for 10887 ; i =  328
#  class is:  13
# computed result for 10888 ; i =  329
#  class is:  8
# computed result for 10890 ; i =  330
#  class is:  11
# computed result for 10891 ; i =  331
#  class is:  13
# computed result for 10892 ; i =  332
#  class is:  2
# computed result for 10894 ; i =  333
#  class is:  1
# computed result for 10896 ; i =  334
#  class is:  18
# computed result for 10900 ; i =  335
#  class is:  10
# computed result for 10905 ; i =  336
#  class is:  8
# computed result for 10908 ; i =  337
#  class is:  8
# computed result for 10910 ; i =  338
#  class is:  18
# computed result for 10917 ; i =  339
#  class is:  18
# computed result for 10920 ; i =  340
#  class is:  16
# computed result for 10926 ; i =  341
#  class is:  4
# computed result for 10938 ; i =  342
#  class is:  4
# computed result for 10943 ; i =  343
#  class is:  14
# computed result for 10946 ; i =  344
#  class is:  16
# computed result for 10950 ; i =  345
#  class is:  13
# computed result for 10952 ; i =  346
#  class is:  4
# computed result for 10953 ; i =  347
#  class is:  3
# computed result for 10957 ; i =  348
#  class is:  11
# computed result for 10958 ; i =  349
#  class is:  10
# computed result for 10959 ; i =  350
#  class is:  6
# computed result for 10962 ; i =  351
#  class is:  17
# computed result for 10965 ; i =  352
#  class is:  3
# computed result for 10966 ; i =  353
#  class is:  20
# computed result for 10967 ; i =  354
#  class is:  16
# computed result for 10970 ; i =  355
#  class is:  11
# computed result for 10972 ; i =  356
#  class is:  16
# computed result for 10974 ; i =  357
#  class is:  17
# computed result for 10979 ; i =  358
#  class is:  15
# computed result for 10980 ; i =  359
#  class is:  4
# computed result for 10986 ; i =  360
#  class is:  10
# computed result for 10988 ; i =  361
#  class is:  14
# computed result for 10989 ; i =  362
#  class is:  13
# computed result for 10990 ; i =  363
#  class is:  8
# computed result for 10996 ; i =  364
#  class is:  14
# computed result for 10997 ; i =  365
#  class is:  9
# computed result for 10999 ; i =  366
#  class is:  4
# computed result for 11003 ; i =  367
#  class is:  18
# computed result for 11006 ; i =  368
#  class is:  6
# computed result for 11015 ; i =  369
#  class is:  20
# computed result for 11016 ; i =  370
#  class is:  7
# computed result for 11022 ; i =  371
#  class is:  4
# computed result for 11023 ; i =  372
#  class is:  6
# computed result for 11025 ; i =  373
#  class is:  11
# computed result for 11030 ; i =  374
#  class is:  8
# computed result for 11032 ; i =  375
#  class is:  1
# computed result for 11037 ; i =  376
#  class is:  18
# computed result for 11039 ; i =  377
#  class is:  11
# computed result for 11048 ; i =  378
#  class is:  11
# computed result for 11051 ; i =  379
#  class is:  17
# computed result for 11052 ; i =  380
#  class is:  4
# computed result for 11054 ; i =  381
#  class is:  15
# computed result for 11055 ; i =  382
#  class is:  6
# computed result for 11059 ; i =  383
#  class is:  8
# computed result for 11061 ; i =  384
#  class is:  11
# computed result for 11066 ; i =  385
#  class is:  13
# computed result for 11069 ; i =  386
#  class is:  4
# computed result for 11073 ; i =  387
#  class is:  4
# computed result for 11075 ; i =  388
#  class is:  13
# computed result for 11080 ; i =  389
#  class is:  14
# computed result for 11085 ; i =  390
#  class is:  17
# computed result for 11091 ; i =  391
#  class is:  6
# computed result for 11096 ; i =  392
#  class is:  8
# computed result for 11100 ; i =  393
#  class is:  7
# computed result for 11101 ; i =  394
#  class is:  4
# computed result for 11103 ; i =  395
#  class is:  17
# computed result for 11104 ; i =  396
#  class is:  19
# computed result for 11107 ; i =  397
#  class is:  8
# computed result for 11108 ; i =  398
#  class is:  14
# computed result for 11122 ; i =  399
#  class is:  19
# computed result for 11124 ; i =  400
#  class is:  4
# computed result for 11125 ; i =  401
#  class is:  13
# computed result for 11126 ; i =  402
#  class is:  9
# computed result for 11132 ; i =  403
#  class is:  11
# computed result for 11134 ; i =  404
#  class is:  4
# computed result for 11136 ; i =  405
#  class is:  4
# computed result for 11141 ; i =  406
#  class is:  14
# computed result for 11144 ; i =  407
#  class is:  20
# computed result for 11145 ; i =  408
#  class is:  13
# computed result for 11152 ; i =  409
#  class is:  14
# computed result for 11154 ; i =  410
#  class is:  8
# computed result for 11156 ; i =  411
#  class is:  4
# computed result for 11159 ; i =  412
#  class is:  18
# computed result for 11162 ; i =  413
#  class is:  11
# computed result for 11165 ; i =  414
#  class is:  4
# computed result for 11166 ; i =  415
#  class is:  12
# computed result for 11170 ; i =  416
#  class is:  5
# computed result for 11172 ; i =  417
#  class is:  18
# computed result for 11175 ; i =  418
#  class is:  4
# computed result for 11177 ; i =  419
#  class is:  13
# computed result for 11179 ; i =  420
#  class is:  11
# computed result for 11181 ; i =  421
#  class is:  20
# computed result for 11187 ; i =  422
#  class is:  20
# computed result for 11188 ; i =  423
#  class is:  7
# computed result for 11189 ; i =  424
#  class is:  3
# computed result for 11191 ; i =  425
#  class is:  6
# computed result for 11197 ; i =  426
#  class is:  7
# computed result for 11201 ; i =  427
#  class is:  5
# computed result for 11203 ; i =  428
#  class is:  11
# computed result for 11206 ; i =  429
#  class is:  8
# computed result for 11207 ; i =  430
#  class is:  11
# computed result for 11210 ; i =  431
#  class is:  15
# computed result for 11214 ; i =  432
#  class is:  14
# computed result for 11223 ; i =  433
#  class is:  11
# computed result for 11225 ; i =  434
#  class is:  2
# computed result for 11226 ; i =  435
#  class is:  12
# computed result for 11228 ; i =  436
#  class is:  6
# computed result for 11229 ; i =  437
#  class is:  4
# computed result for 11233 ; i =  438
#  class is:  5
# computed result for 11236 ; i =  439
#  class is:  4
# computed result for 11237 ; i =  440
#  class is:  17
# computed result for 11238 ; i =  441
#  class is:  6
# computed result for 11240 ; i =  442
#  class is:  4
# computed result for 11242 ; i =  443
#  class is:  16
# computed result for 11246 ; i =  444
#  class is:  14
# computed result for 11249 ; i =  445
#  class is:  13
# computed result for 11251 ; i =  446
#  class is:  3
# computed result for 11254 ; i =  447
#  class is:  11
# computed result for 11263 ; i =  448
#  class is:  11
# computed result for 11265 ; i =  449
#  class is:  14
# computed result for 11269 ; i =  450
#  class is:  18
# computed result for 11272 ; i =  451
#  class is:  20
# computed result for 11274 ; i =  452
#  class is:  4
# computed result for 11277 ; i =  453
#  class is:  9
# computed result for 11281 ; i =  454
#  class is:  14
# computed result for 11282 ; i =  455
#  class is:  4
# computed result for 11284 ; i =  456
#  class is:  10
# computed result for 11285 ; i =  457
#  class is:  6
# computed result for 11286 ; i =  458
#  class is:  17
# computed result for 11289 ; i =  459
#  class is:  9
# computed result for 11291 ; i =  460
#  class is:  6
# computed result for 11293 ; i =  461
#  class is:  1
# computed result for 11294 ; i =  462
#  class is:  6
# computed result for 11298 ; i =  463
#  class is:  15
# computed result for 11302 ; i =  464
#  class is:  20
# computed result for 11307 ; i =  465
#  class is:  16
# computed result for 11311 ; i =  466
#  class is:  15
# computed result for 11312 ; i =  467
#  class is:  19
# computed result for 11315 ; i =  468
#  class is:  14
# computed result for 11316 ; i =  469
#  class is:  4
# computed result for 11317 ; i =  470
#  class is:  1
# computed result for 11318 ; i =  471
#  class is:  16
# computed result for 11322 ; i =  472
#  class is:  12
# computed result for 11329 ; i =  473
#  class is:  9
# computed result for 11330 ; i =  474
#  class is:  1
# computed result for 11332 ; i =  475
#  class is:  16
# computed result for 11333 ; i =  476
#  class is:  6
# computed result for 11335 ; i =  477
#  class is:  4
# computed result for 11337 ; i =  478
#  class is:  6
# computed result for 11338 ; i =  479
#  class is:  8
# computed result for 11342 ; i =  480
#  class is:  1
# computed result for 11343 ; i =  481
#  class is:  17
# computed result for 11352 ; i =  482
#  class is:  4
# computed result for 11353 ; i =  483
#  class is:  5
# computed result for 11354 ; i =  484
#  class is:  17
# computed result for 11355 ; i =  485
#  class is:  1
# computed result for 11357 ; i =  486
#  class is:  11
# computed result for 11358 ; i =  487
#  class is:  12
# computed result for 11359 ; i =  488
#  class is:  9
# computed result for 11360 ; i =  489
#  class is:  4
# computed result for 11361 ; i =  490
#  class is:  4
# computed result for 11362 ; i =  491
#  class is:  10
# computed result for 11365 ; i =  492
#  class is:  13
# computed result for 11366 ; i =  493
#  class is:  11
# computed result for 11367 ; i =  494
#  class is:  11
# computed result for 11372 ; i =  495
#  class is:  20
# computed result for 11374 ; i =  496
#  class is:  4
# computed result for 11376 ; i =  497
#  class is:  2
# computed result for 11381 ; i =  498
#  class is:  8
# computed result for 11382 ; i =  499
#  class is:  17
# computed result for 11388 ; i =  500
#  class is:  6
# computed result for 11392 ; i =  501
#  class is:  9
# computed result for 11393 ; i =  502
#  class is:  8
# computed result for 11394 ; i =  503
#  class is:  13
# computed result for 11397 ; i =  504
#  class is:  18
# computed result for 11400 ; i =  505
#  class is:  11
# computed result for 11401 ; i =  506
#  class is:  18
# computed result for 11404 ; i =  507
#  class is:  8
# computed result for 11411 ; i =  508
#  class is:  3
# computed result for 11415 ; i =  509
#  class is:  10
# computed result for 11416 ; i =  510
#  class is:  1
# computed result for 11417 ; i =  511
#  class is:  9
# computed result for 11418 ; i =  512
#  class is:  12
# computed result for 11419 ; i =  513
#  class is:  11
# computed result for 11424 ; i =  514
#  class is:  17
# computed result for 11427 ; i =  515
#  class is:  8
# computed result for 11430 ; i =  516
#  class is:  5
# computed result for 11432 ; i =  517
#  class is:  7
# computed result for 11435 ; i =  518
#  class is:  8
# computed result for 11436 ; i =  519
#  class is:  2
# computed result for 11439 ; i =  520
#  class is:  14
# computed result for 11440 ; i =  521
#  class is:  9
# computed result for 11442 ; i =  522
#  class is:  4
# computed result for 11445 ; i =  523
#  class is:  9
# computed result for 11447 ; i =  524
#  class is:  6
# computed result for 11450 ; i =  525
#  class is:  9
# computed result for 11452 ; i =  526
#  class is:  3
# computed result for 11457 ; i =  527
#  class is:  7
# computed result for 11458 ; i =  528
#  class is:  20
# computed result for 11459 ; i =  529
#  class is:  7
# computed result for 11462 ; i =  530
#  class is:  14
# computed result for 11463 ; i =  531
#  class is:  14
# computed result for 11464 ; i =  532
#  class is:  1
# computed result for 11465 ; i =  533
#  class is:  14
# computed result for 11470 ; i =  534
#  class is:  9
# computed result for 11472 ; i =  535
#  class is:  14
# computed result for 11474 ; i =  536
#  class is:  15
# computed result for 11476 ; i =  537
#  class is:  9
# computed result for 11482 ; i =  538
#  class is:  20
# computed result for 11484 ; i =  539
#  class is:  20
# computed result for 11491 ; i =  540
#  class is:  13
# computed result for 11492 ; i =  541
#  class is:  19
# computed result for 11494 ; i =  542
#  class is:  14
# computed result for 11500 ; i =  543
#  class is:  4
# computed result for 11504 ; i =  544
#  class is:  4
# computed result for 11508 ; i =  545
#  class is:  9
# computed result for 11512 ; i =  546
#  class is:  17
# computed result for 11513 ; i =  547
#  class is:  12
# computed result for 11517 ; i =  548
#  class is:  18
# computed result for 11520 ; i =  549
#  class is:  13
# computed result for 11522 ; i =  550
#  class is:  9
# computed result for 11530 ; i =  551
#  class is:  20
# computed result for 11533 ; i =  552
#  class is:  9
# computed result for 11540 ; i =  553
#  class is:  6
# computed result for 11543 ; i =  554
#  class is:  11
# computed result for 11545 ; i =  555
#  class is:  16
# computed result for 11546 ; i =  556
#  class is:  2
# computed result for 11550 ; i =  557
#  class is:  7
# computed result for 11551 ; i =  558
#  class is:  9
# computed result for 11554 ; i =  559
#  class is:  2
# computed result for 11556 ; i =  560
#  class is:  6
# computed result for 11562 ; i =  561
#  class is:  14
# computed result for 11566 ; i =  562
#  class is:  9
# computed result for 11574 ; i =  563
#  class is:  11
# computed result for 11575 ; i =  564
#  class is:  13
# computed result for 11576 ; i =  565
#  class is:  8
# computed result for 11578 ; i =  566
#  class is:  18
# computed result for 11579 ; i =  567
#  class is:  19
# computed result for 11591 ; i =  568
#  class is:  17
# computed result for 11593 ; i =  569
#  class is:  1
# computed result for 11594 ; i =  570
#  class is:  9
# computed result for 11595 ; i =  571
#  class is:  9
# computed result for 11597 ; i =  572
#  class is:  11
# computed result for 11604 ; i =  573
#  class is:  15
# computed result for 11606 ; i =  574
#  class is:  5
# computed result for 11610 ; i =  575
#  class is:  12
# computed result for 11612 ; i =  576
#  class is:  19
# computed result for 11613 ; i =  577
#  class is:  4
# computed result for 11614 ; i =  578
#  class is:  3
# computed result for 11615 ; i =  579
#  class is:  4
# computed result for 11617 ; i =  580
#  class is:  14
# computed result for 11621 ; i =  581
#  class is:  15
# computed result for 11624 ; i =  582
#  class is:  4
# computed result for 11629 ; i =  583
#  class is:  6
# computed result for 11634 ; i =  584
#  class is:  8
# computed result for 11642 ; i =  585
#  class is:  10
# computed result for 11643 ; i =  586
#  class is:  19
# computed result for 11647 ; i =  587
#  class is:  9
# computed result for 11650 ; i =  588
#  class is:  6
# computed result for 11651 ; i =  589
#  class is:  17
# computed result for 11657 ; i =  590
#  class is:  16
# computed result for 11659 ; i =  591
#  class is:  18
# computed result for 11667 ; i =  592
#  class is:  5
# computed result for 11673 ; i =  593
#  class is:  18
# computed result for 11675 ; i =  594
#  class is:  17
# computed result for 11678 ; i =  595
#  class is:  19
# computed result for 11680 ; i =  596
#  class is:  13
# computed result for 11681 ; i =  597
#  class is:  17
# computed result for 11683 ; i =  598
#  class is:  18
# computed result for 11684 ; i =  599
#  class is:  18
# computed result for 11685 ; i =  600
#  class is:  9
# computed result for 11688 ; i =  601
#  class is:  17
# computed result for 11691 ; i =  602
#  class is:  6
# computed result for 11693 ; i =  603
#  class is:  4
# computed result for 11694 ; i =  604
#  class is:  6
# computed result for 11695 ; i =  605
#  class is:  1
# computed result for 11697 ; i =  606
#  class is:  13
# computed result for 11700 ; i =  607
#  class is:  9
# computed result for 11704 ; i =  608
#  class is:  9
# computed result for 11705 ; i =  609
#  class is:  4
# computed result for 11712 ; i =  610
#  class is:  12
# computed result for 11713 ; i =  611
#  class is:  1
# computed result for 11716 ; i =  612
#  class is:  14
# computed result for 11719 ; i =  613
#  class is:  8
# computed result for 11723 ; i =  614
#  class is:  17
# computed result for 11726 ; i =  615
#  class is:  10
# computed result for 11732 ; i =  616
#  class is:  8
# computed result for 11733 ; i =  617
#  class is:  6
# computed result for 11737 ; i =  618
#  class is:  20
# computed result for 11739 ; i =  619
#  class is:  11
# computed result for 11748 ; i =  620
#  class is:  16
# computed result for 11750 ; i =  621
#  class is:  4
# computed result for 11756 ; i =  622
#  class is:  13
# computed result for 11759 ; i =  623
#  class is:  9
# computed result for 11764 ; i =  624
#  class is:  6
# computed result for 11766 ; i =  625
#  class is:  7
# computed result for 11767 ; i =  626
#  class is:  16
# computed result for 11769 ; i =  627
#  class is:  20
# computed result for 11775 ; i =  628
#  class is:  17
# computed result for 11777 ; i =  629
#  class is:  6
# computed result for 11778 ; i =  630
#  class is:  9
# computed result for 11779 ; i =  631
#  class is:  13
# computed result for 11783 ; i =  632
#  class is:  18
# computed result for 11786 ; i =  633
#  class is:  11
# computed result for 11787 ; i =  634
#  class is:  17
# computed result for 11789 ; i =  635
#  class is:  4
# computed result for 11792 ; i =  636
#  class is:  7
# computed result for 11795 ; i =  637
#  class is:  4
# computed result for 11796 ; i =  638
#  class is:  4
# computed result for 11798 ; i =  639
#  class is:  12
# computed result for 11820 ; i =  640
#  class is:  2
# computed result for 11821 ; i =  641
#  class is:  5
# computed result for 11823 ; i =  642
#  class is:  4
# computed result for 11824 ; i =  643
#  class is:  19
# computed result for 11834 ; i =  644
#  class is:  20
# computed result for 11835 ; i =  645
#  class is:  13
# computed result for 11839 ; i =  646
#  class is:  1
# computed result for 11841 ; i =  647
#  class is:  4
# computed result for 11842 ; i =  648
#  class is:  8
# computed result for 11844 ; i =  649
#  class is:  1
# computed result for 11846 ; i =  650
#  class is:  20
# computed result for 11847 ; i =  651
#  class is:  8
# computed result for 11849 ; i =  652
#  class is:  17
# computed result for 11851 ; i =  653
#  class is:  4
# computed result for 11852 ; i =  654
#  class is:  17
# computed result for 11856 ; i =  655
#  class is:  13
# computed result for 11857 ; i =  656
#  class is:  17
# computed result for 11859 ; i =  657
#  class is:  7
# computed result for 11860 ; i =  658
#  class is:  10
# computed result for 11866 ; i =  659
#  class is:  17
# computed result for 11867 ; i =  660
#  class is:  8
# computed result for 11868 ; i =  661
#  class is:  17
# computed result for 11872 ; i =  662
#  class is:  19
# computed result for 11875 ; i =  663
#  class is:  11
# computed result for 11883 ; i =  664
#  class is:  20
# computed result for 11887 ; i =  665
#  class is:  19
# computed result for 11888 ; i =  666
#  class is:  11
# computed result for 11891 ; i =  667
#  class is:  16
# computed result for 11895 ; i =  668
#  class is:  5
# computed result for 11898 ; i =  669
#  class is:  16
# computed result for 11903 ; i =  670
#  class is:  15
# computed result for 11904 ; i =  671
#  class is:  14
# computed result for 11912 ; i =  672
#  class is:  10
# computed result for 11913 ; i =  673
#  class is:  19
# computed result for 11916 ; i =  674
#  class is:  13
# computed result for 11920 ; i =  675
#  class is:  9
# computed result for 11921 ; i =  676
#  class is:  19
# computed result for 11923 ; i =  677
#  class is:  17
# computed result for 11924 ; i =  678
#  class is:  9
# computed result for 11925 ; i =  679
#  class is:  20
# computed result for 11926 ; i =  680
#  class is:  4
# computed result for 11927 ; i =  681
#  class is:  14
# computed result for 11935 ; i =  682
#  class is:  15
# computed result for 11939 ; i =  683
#  class is:  7
# computed result for 11941 ; i =  684
#  class is:  4
# computed result for 11942 ; i =  685
#  class is:  12
# computed result for 11944 ; i =  686
#  class is:  11
# computed result for 11945 ; i =  687
#  class is:  15
# computed result for 11946 ; i =  688
#  class is:  20
# computed result for 11947 ; i =  689
#  class is:  17
# computed result for 11948 ; i =  690
#  class is:  10
# computed result for 11949 ; i =  691
#  class is:  14
# computed result for 11950 ; i =  692
#  class is:  4
# computed result for 11952 ; i =  693
#  class is:  19
# computed result for 11953 ; i =  694
#  class is:  6
# computed result for 11954 ; i =  695
#  class is:  5
# computed result for 11961 ; i =  696
#  class is:  17
# computed result for 11962 ; i =  697
#  class is:  6
# computed result for 11963 ; i =  698
#  class is:  4
# computed result for 11964 ; i =  699
#  class is:  15
# computed result for 11965 ; i =  700
#  class is:  18
# computed result for 11966 ; i =  701
#  class is:  10
# computed result for 11971 ; i =  702
#  class is:  11
# computed result for 11974 ; i =  703
#  class is:  2
# computed result for 11982 ; i =  704
#  class is:  9
# computed result for 11984 ; i =  705
#  class is:  20
# computed result for 11985 ; i =  706
#  class is:  1
# computed result for 11986 ; i =  707
#  class is:  17
# computed result for 11987 ; i =  708
#  class is:  12
# computed result for 11988 ; i =  709
#  class is:  4
# computed result for 11990 ; i =  710
#  class is:  10
# computed result for 11991 ; i =  711
#  class is:  7
# computed result for 11992 ; i =  712
#  class is:  15
# computed result for 11993 ; i =  713
#  class is:  18
# computed result for 11996 ; i =  714
#  class is:  4
# computed result for 11998 ; i =  715
#  class is:  8
# computed result for 11999 ; i =  716
#  class is:  11
# computed result for 12001 ; i =  717
#  class is:  15
# computed result for 12002 ; i =  718
#  class is:  20
# computed result for 12004 ; i =  719
#  class is:  8
# computed result for 12008 ; i =  720
#  class is:  20
# computed result for 12009 ; i =  721
#  class is:  8
# computed result for 12011 ; i =  722
#  class is:  12
# computed result for 12018 ; i =  723
#  class is:  9
# computed result for 12020 ; i =  724
#  class is:  3
# computed result for 12021 ; i =  725
#  class is:  16
# computed result for 12024 ; i =  726
#  class is:  15
# computed result for 12029 ; i =  727
#  class is:  15
# computed result for 12030 ; i =  728
#  class is:  6
# computed result for 12035 ; i =  729
#  class is:  9
# computed result for 12038 ; i =  730
#  class is:  20
# computed result for 12039 ; i =  731
#  class is:  1
# computed result for 12049 ; i =  732
#  class is:  4
# computed result for 12052 ; i =  733
#  class is:  6
# computed result for 12053 ; i =  734
#  class is:  2
# computed result for 12054 ; i =  735
#  class is:  13
# computed result for 12058 ; i =  736
#  class is:  4
# computed result for 12062 ; i =  737
#  class is:  1
# computed result for 12064 ; i =  738
#  class is:  19
# computed result for 12072 ; i =  739
#  class is:  7
# computed result for 12074 ; i =  740
#  class is:  19
# computed result for 12081 ; i =  741
#  class is:  5
# computed result for 12082 ; i =  742
#  class is:  10
# computed result for 12087 ; i =  743
#  class is:  6
# computed result for 12089 ; i =  744
#  class is:  14
# computed result for 12091 ; i =  745
#  class is:  16
# computed result for 12093 ; i =  746
#  class is:  18
# computed result for 12094 ; i =  747
#  class is:  8
# computed result for 12095 ; i =  748
#  class is:  14
# computed result for 12099 ; i =  749
#  class is:  11
# computed result for 12100 ; i =  750
#  class is:  10
# computed result for 12101 ; i =  751
#  class is:  1
# computed result for 12102 ; i =  752
#  class is:  19
# computed result for 12105 ; i =  753
#  class is:  6
# computed result for 12106 ; i =  754
#  class is:  12
# computed result for 12112 ; i =  755
#  class is:  18
# computed result for 12114 ; i =  756
#  class is:  12
# computed result for 12121 ; i =  757
#  class is:  19
# computed result for 12124 ; i =  758
#  class is:  14
# computed result for 12127 ; i =  759
#  class is:  9
# computed result for 12129 ; i =  760
#  class is:  9
# computed result for 12130 ; i =  761
#  class is:  10
# computed result for 12132 ; i =  762
#  class is:  5
# computed result for 12133 ; i =  763
#  class is:  19
# computed result for 12149 ; i =  764
#  class is:  17
# computed result for 12152 ; i =  765
#  class is:  2
# computed result for 12156 ; i =  766
#  class is:  14
# computed result for 12157 ; i =  767
#  class is:  11
# computed result for 12158 ; i =  768
#  class is:  20
# computed result for 12159 ; i =  769
#  class is:  17
# computed result for 12160 ; i =  770
#  class is:  6
# computed result for 12161 ; i =  771
#  class is:  8
# computed result for 12166 ; i =  772
#  class is:  8
# computed result for 12170 ; i =  773
#  class is:  12
# computed result for 12171 ; i =  774
#  class is:  5
# computed result for 12172 ; i =  775
#  class is:  8
# computed result for 12175 ; i =  776
#  class is:  11
# computed result for 12176 ; i =  777
#  class is:  18
# computed result for 12179 ; i =  778
#  class is:  10
# computed result for 12184 ; i =  779
#  class is:  2
# computed result for 12188 ; i =  780
#  class is:  9
# computed result for 12190 ; i =  781
#  class is:  13
# computed result for 12196 ; i =  782
#  class is:  11
# computed result for 12197 ; i =  783
#  class is:  12
# computed result for 12198 ; i =  784
#  class is:  18
# computed result for 12201 ; i =  785
#  class is:  10
# computed result for 12203 ; i =  786
#  class is:  12
# computed result for 12205 ; i =  787
#  class is:  2
# computed result for 12206 ; i =  788
#  class is:  6
# computed result for 12208 ; i =  789
#  class is:  2
# computed result for 12209 ; i =  790
#  class is:  3
# computed result for 12211 ; i =  791
#  class is:  17
# computed result for 12215 ; i =  792
#  class is:  4
# computed result for 12217 ; i =  793
#  class is:  6
# computed result for 12218 ; i =  794
#  class is:  19
# computed result for 12219 ; i =  795
#  class is:  18
# computed result for 12224 ; i =  796
#  class is:  11
# computed result for 12227 ; i =  797
#  class is:  10
# computed result for 12231 ; i =  798
#  class is:  18
# computed result for 12233 ; i =  799
#  class is:  18
# computed result for 12234 ; i =  800
#  class is:  7
# computed result for 12237 ; i =  801
#  class is:  2
# computed result for 12240 ; i =  802
#  class is:  8
# computed result for 12242 ; i =  803
#  class is:  9
# computed result for 12243 ; i =  804
#  class is:  4
# computed result for 12248 ; i =  805
#  class is:  8
# computed result for 12251 ; i =  806
#  class is:  9
# computed result for 12268 ; i =  807
#  class is:  1
# computed result for 12280 ; i =  808
#  class is:  9
# computed result for 12282 ; i =  809
#  class is:  9
# computed result for 12286 ; i =  810
#  class is:  10
# computed result for 12287 ; i =  811
#  class is:  13
# computed result for 12289 ; i =  812
#  class is:  9
# computed result for 12290 ; i =  813
#  class is:  12
# computed result for 12294 ; i =  814
#  class is:  10
# computed result for 12299 ; i =  815
#  class is:  6
# computed result for 12301 ; i =  816
#  class is:  18
# computed result for 12302 ; i =  817
#  class is:  5
# computed result for 12306 ; i =  818
#  class is:  18
# computed result for 12308 ; i =  819
#  class is:  20
# computed result for 12311 ; i =  820
#  class is:  9
# computed result for 12318 ; i =  821
#  class is:  18
# computed result for 12323 ; i =  822
#  class is:  6
# computed result for 12326 ; i =  823
#  class is:  7
# computed result for 12329 ; i =  824
#  class is:  18
# computed result for 12334 ; i =  825
#  class is:  14
# computed result for 12336 ; i =  826
#  class is:  6
# computed result for 12337 ; i =  827
#  class is:  14
# computed result for 12339 ; i =  828
#  class is:  9
# computed result for 12340 ; i =  829
#  class is:  7
# computed result for 12342 ; i =  830
#  class is:  4
# computed result for 12343 ; i =  831
#  class is:  5
# computed result for 12344 ; i =  832
#  class is:  14
# computed result for 12348 ; i =  833
#  class is:  12
# computed result for 12359 ; i =  834
#  class is:  17
# computed result for 12361 ; i =  835
#  class is:  4
# computed result for 12362 ; i =  836
#  class is:  4
# computed result for 12363 ; i =  837
#  class is:  9
# computed result for 12365 ; i =  838
#  class is:  8
# computed result for 12368 ; i =  839
#  class is:  16
# computed result for 12374 ; i =  840
#  class is:  19
# computed result for 12375 ; i =  841
#  class is:  3
# computed result for 12377 ; i =  842
#  class is:  8
# computed result for 12378 ; i =  843
#  class is:  8
# computed result for 12380 ; i =  844
#  class is:  16
# computed result for 12387 ; i =  845
#  class is:  8
# computed result for 12388 ; i =  846
#  class is:  3
# computed result for 12389 ; i =  847
#  class is:  11
# computed result for 12390 ; i =  848
#  class is:  8
# computed result for 12397 ; i =  849
#  class is:  12
# computed result for 12398 ; i =  850
#  class is:  20
# computed result for 12401 ; i =  851
#  class is:  19
# computed result for 12404 ; i =  852
#  class is:  1
# computed result for 12405 ; i =  853
#  class is:  18
# computed result for 12408 ; i =  854
#  class is:  2
# computed result for 12409 ; i =  855
#  class is:  18
# computed result for 12410 ; i =  856
#  class is:  14
# computed result for 12412 ; i =  857
#  class is:  9
# computed result for 12413 ; i =  858
#  class is:  9
# computed result for 12414 ; i =  859
#  class is:  18
# computed result for 12416 ; i =  860
#  class is:  6
# computed result for 12417 ; i =  861
#  class is:  11
# computed result for 12420 ; i =  862
#  class is:  13
# computed result for 12421 ; i =  863
#  class is:  19
# computed result for 12428 ; i =  864
#  class is:  19
# computed result for 12433 ; i =  865
#  class is:  13
# computed result for 12440 ; i =  866
#  class is:  11
# computed result for 12441 ; i =  867
#  class is:  11
# computed result for 12444 ; i =  868
#  class is:  18
# computed result for 12445 ; i =  869
#  class is:  17
# computed result for 12447 ; i =  870
#  class is:  2
# computed result for 12448 ; i =  871
#  class is:  9
# computed result for 12450 ; i =  872
#  class is:  12
# computed result for 12452 ; i =  873
#  class is:  14
# computed result for 12454 ; i =  874
#  class is:  14
# computed result for 12457 ; i =  875
#  class is:  9
# computed result for 12461 ; i =  876
#  class is:  1
# computed result for 12464 ; i =  877
#  class is:  8
# computed result for 12465 ; i =  878
#  class is:  14
# computed result for 12467 ; i =  879
#  class is:  4
# computed result for 12469 ; i =  880
#  class is:  17
# computed result for 12471 ; i =  881
#  class is:  12
# computed result for 12472 ; i =  882
#  class is:  1
# computed result for 12473 ; i =  883
#  class is:  20
# computed result for 12475 ; i =  884
#  class is:  4
# computed result for 12476 ; i =  885
#  class is:  5
# computed result for 12479 ; i =  886
#  class is:  10
# computed result for 12483 ; i =  887
#  class is:  19
# computed result for 12487 ; i =  888
#  class is:  9
# computed result for 12490 ; i =  889
#  class is:  9
# computed result for 12493 ; i =  890
#  class is:  1
# computed result for 12495 ; i =  891
#  class is:  16
# computed result for 12496 ; i =  892
#  class is:  8
# computed result for 12499 ; i =  893
# ...
#  class is:  15
# computed result for 23158 ; i =  4698
#  class is:  12
# computed result for 23159 ; i =  4699
#  class is:  15
# computed result for 23163 ; i =  4700
#  class is:  8
# computed result for 23167 ; i =  4701
#  class is:  16
# computed result for 23168 ; i =  4702
#  class is:  17
# computed result for 23169 ; i =  4703
#  class is:  8
# computed result for 23171 ; i =  4704
#  class is:  11
# computed result for 23174 ; i =  4705
#  class is:  7
# computed result for 23175 ; i =  4706
#  class is:  15
# computed result for 23177 ; i =  4707
#  class is:  12
# computed result for 23178 ; i =  4708
#  class is:  16
# computed result for 23187 ; i =  4709
#  class is:  7
# computed result for 23189 ; i =  4710
#  class is:  19
# computed result for 23194 ; i =  4711
#  class is:  1
# computed result for 23195 ; i =  4712
#  class is:  8
# computed result for 23196 ; i =  4713
#  class is:  18
# computed result for 23198 ; i =  4714
#  class is:  8
# computed result for 23199 ; i =  4715
#  class is:  4
# computed result for 23204 ; i =  4716
#  class is:  13
# computed result for 23209 ; i =  4717
#  class is:  14
# computed result for 23211 ; i =  4718
#  class is:  14
# computed result for 23216 ; i =  4719
#  class is:  4
# computed result for 23217 ; i =  4720
#  class is:  20
# computed result for 23218 ; i =  4721
#  class is:  2
# computed result for 23219 ; i =  4722
#  class is:  15
# computed result for 23220 ; i =  4723
#  class is:  19
# computed result for 23222 ; i =  4724
#  class is:  20
# computed result for 23225 ; i =  4725
#  class is:  18
# computed result for 23228 ; i =  4726
#  class is:  5
# computed result for 23231 ; i =  4727
#  class is:  7
# computed result for 23234 ; i =  4728
#  class is:  9
# computed result for 23235 ; i =  4729
#  class is:  11
# computed result for 23239 ; i =  4730
#  class is:  11
# computed result for 23244 ; i =  4731
#  class is:  20
# computed result for 23246 ; i =  4732
#  class is:  8
# computed result for 23247 ; i =  4733
#  class is:  15
# computed result for 23255 ; i =  4734
#  class is:  14
# computed result for 23256 ; i =  4735
#  class is:  16
# computed result for 23261 ; i =  4736
#  class is:  4
# computed result for 23265 ; i =  4737
#  class is:  6
# computed result for 23266 ; i =  4738
#  class is:  9
# computed result for 23276 ; i =  4739
#  class is:  15
# computed result for 23279 ; i =  4740
#  class is:  4
# computed result for 23282 ; i =  4741
#  class is:  6
# computed result for 23285 ; i =  4742
#  class is:  1
# computed result for 23286 ; i =  4743
#  class is:  4
# computed result for 23292 ; i =  4744
#  class is:  1
# computed result for 23294 ; i =  4745
#  class is:  9
# computed result for 23297 ; i =  4746
#  class is:  3
# computed result for 23300 ; i =  4747
#  class is:  4
# computed result for 23302 ; i =  4748
#  class is:  4
# computed result for 23304 ; i =  4749
#  class is:  10
# computed result for 23306 ; i =  4750
#  class is:  13
# computed result for 23307 ; i =  4751
#  class is:  11
# computed result for 23312 ; i =  4752
#  class is:  16
# computed result for 23315 ; i =  4753
#  class is:  4
# computed result for 23317 ; i =  4754
#  class is:  1
# computed result for 23319 ; i =  4755
#  class is:  20
# computed result for 23322 ; i =  4756
#  class is:  12
# computed result for 23323 ; i =  4757
#  class is:  11
# computed result for 23329 ; i =  4758
#  class is:  3
# computed result for 23331 ; i =  4759
#  class is:  4
# computed result for 23333 ; i =  4760
#  class is:  18
# computed result for 23336 ; i =  4761
#  class is:  11
# computed result for 23337 ; i =  4762
#  class is:  6
# computed result for 23339 ; i =  4763
#  class is:  18
# computed result for 23342 ; i =  4764
#  class is:  6
# computed result for 23344 ; i =  4765
#  class is:  12
# computed result for 23347 ; i =  4766
#  class is:  15
# computed result for 23349 ; i =  4767
#  class is:  9
# computed result for 23350 ; i =  4768
#  class is:  14
# computed result for 23354 ; i =  4769
#  class is:  9
# computed result for 23362 ; i =  4770
#  class is:  7
# computed result for 23363 ; i =  4771
#  class is:  3
# computed result for 23364 ; i =  4772
#  class is:  15
# computed result for 23367 ; i =  4773
#  class is:  15
# computed result for 23372 ; i =  4774
#  class is:  17
# computed result for 23375 ; i =  4775
#  class is:  20
# computed result for 23382 ; i =  4776
#  class is:  16
# computed result for 23389 ; i =  4777
#  class is:  8
# computed result for 23393 ; i =  4778
#  class is:  16
# computed result for 23396 ; i =  4779
#  class is:  1
# computed result for 23399 ; i =  4780
#  class is:  3
# computed result for 23401 ; i =  4781
#  class is:  6
# computed result for 23403 ; i =  4782
#  class is:  13
# computed result for 23406 ; i =  4783
#  class is:  20
# computed result for 23409 ; i =  4784
#  class is:  9
# computed result for 23414 ; i =  4785
#  class is:  6
# computed result for 23415 ; i =  4786
#  class is:  15
# computed result for 23416 ; i =  4787
#  class is:  11
# computed result for 23418 ; i =  4788
#  class is:  20
# computed result for 23422 ; i =  4789
#  class is:  6
# computed result for 23424 ; i =  4790
#  class is:  19
# computed result for 23426 ; i =  4791
#  class is:  5
# computed result for 23429 ; i =  4792
#  class is:  16
# computed result for 23436 ; i =  4793
#  class is:  8
# computed result for 23437 ; i =  4794
#  class is:  4
# computed result for 23442 ; i =  4795
#  class is:  4
# computed result for 23443 ; i =  4796
#  class is:  20
# computed result for 23444 ; i =  4797
#  class is:  15
# computed result for 23446 ; i =  4798
#  class is:  8
# computed result for 23448 ; i =  4799
#  class is:  8
# computed result for 23451 ; i =  4800
#  class is:  15
# computed result for 23456 ; i =  4801
#  class is:  1
# computed result for 23462 ; i =  4802
#  class is:  20
# computed result for 23465 ; i =  4803
#  class is:  5
# computed result for 23468 ; i =  4804
#  class is:  4
# computed result for 23470 ; i =  4805
#  class is:  17
# computed result for 23476 ; i =  4806
#  class is:  18
# computed result for 23477 ; i =  4807
#  class is:  19
# computed result for 23481 ; i =  4808
#  class is:  3
# computed result for 23484 ; i =  4809
#  class is:  11
# computed result for 23492 ; i =  4810
#  class is:  17
# computed result for 23497 ; i =  4811
#  class is:  7
# computed result for 23508 ; i =  4812
#  class is:  6
# computed result for 23512 ; i =  4813
#  class is:  15
# computed result for 23514 ; i =  4814
#  class is:  4
# computed result for 23515 ; i =  4815
#  class is:  4
# computed result for 23516 ; i =  4816
#  class is:  4
# computed result for 23524 ; i =  4817
#  class is:  12
# computed result for 23526 ; i =  4818
#  class is:  16
# computed result for 23528 ; i =  4819
#  class is:  3
# computed result for 23530 ; i =  4820
#  class is:  9
# computed result for 23533 ; i =  4821
#  class is:  8
# computed result for 23535 ; i =  4822
#  class is:  12
# computed result for 23545 ; i =  4823
#  class is:  15
# computed result for 23546 ; i =  4824
#  class is:  13
# computed result for 23553 ; i =  4825
#  class is:  17
# computed result for 23554 ; i =  4826
#  class is:  1
# computed result for 23555 ; i =  4827
#  class is:  11
# computed result for 23560 ; i =  4828
#  class is:  16
# computed result for 23563 ; i =  4829
#  class is:  19
# computed result for 23565 ; i =  4830
#  class is:  4
# computed result for 23569 ; i =  4831
#  class is:  14
# computed result for 23570 ; i =  4832
#  class is:  14
# computed result for 23572 ; i =  4833
#  class is:  20
# computed result for 23584 ; i =  4834
#  class is:  7
# computed result for 23585 ; i =  4835
#  class is:  11
# computed result for 23588 ; i =  4836
#  class is:  8
# computed result for 23591 ; i =  4837
#  class is:  8
# computed result for 23594 ; i =  4838
#  class is:  10
# computed result for 23600 ; i =  4839
#  class is:  1
# computed result for 23607 ; i =  4840
#  class is:  1
# computed result for 23613 ; i =  4841
#  class is:  14
# computed result for 23617 ; i =  4842
#  class is:  8
# computed result for 23621 ; i =  4843
#  class is:  19
# computed result for 23622 ; i =  4844
#  class is:  9
# computed result for 23623 ; i =  4845
#  class is:  8
# computed result for 23626 ; i =  4846
#  class is:  4
# computed result for 23627 ; i =  4847
#  class is:  20
# computed result for 23628 ; i =  4848
#  class is:  18
# computed result for 23629 ; i =  4849
#  class is:  15
# computed result for 23630 ; i =  4850
#  class is:  2
# computed result for 23631 ; i =  4851
#  class is:  2
# computed result for 23636 ; i =  4852
#  class is:  2
# computed result for 23637 ; i =  4853
#  class is:  19
# computed result for 23640 ; i =  4854
#  class is:  1
# computed result for 23642 ; i =  4855
#  class is:  4
# computed result for 23646 ; i =  4856
#  class is:  10
# computed result for 23648 ; i =  4857
#  class is:  14
# computed result for 23649 ; i =  4858
#  class is:  11
# computed result for 23650 ; i =  4859
#  class is:  17
# computed result for 23652 ; i =  4860
#  class is:  16
# computed result for 23653 ; i =  4861
#  class is:  18
# computed result for 23655 ; i =  4862
#  class is:  9
# computed result for 23657 ; i =  4863
#  class is:  9
# computed result for 23663 ; i =  4864
#  class is:  14
# computed result for 23665 ; i =  4865
#  class is:  11
# computed result for 23669 ; i =  4866
#  class is:  12
# computed result for 23673 ; i =  4867
#  class is:  19
# computed result for 23674 ; i =  4868
#  class is:  9
# computed result for 23678 ; i =  4869
#  class is:  9
# computed result for 23679 ; i =  4870
#  class is:  4
# computed result for 23680 ; i =  4871
#  class is:  8
# computed result for 23685 ; i =  4872
#  class is:  16
# computed result for 23687 ; i =  4873
#  class is:  8
# computed result for 23696 ; i =  4874
#  class is:  9
# computed result for 23697 ; i =  4875
#  class is:  18
# computed result for 23699 ; i =  4876
#  class is:  11
# computed result for 23700 ; i =  4877
#  class is:  9
# computed result for 23702 ; i =  4878
#  class is:  4
# computed result for 23703 ; i =  4879
#  class is:  16
# computed result for 23704 ; i =  4880
#  class is:  9
# computed result for 23706 ; i =  4881
#  class is:  20
# computed result for 23707 ; i =  4882
#  class is:  9
# computed result for 23708 ; i =  4883
#  class is:  4
# computed result for 23709 ; i =  4884
#  class is:  20
# computed result for 23710 ; i =  4885
#  class is:  7
# computed result for 23711 ; i =  4886
#  class is:  14
# computed result for 23713 ; i =  4887
#  class is:  8
# computed result for 23717 ; i =  4888
#  class is:  4
# computed result for 23718 ; i =  4889
#  class is:  19
# computed result for 23721 ; i =  4890
#  class is:  2
# computed result for 23726 ; i =  4891
#  class is:  4
# computed result for 23731 ; i =  4892
#  class is:  3
# computed result for 23739 ; i =  4893
#  class is:  14
# computed result for 23744 ; i =  4894
#  class is:  17
# computed result for 23745 ; i =  4895
#  class is:  12
# computed result for 23746 ; i =  4896
#  class is:  3
# computed result for 23748 ; i =  4897
#  class is:  11
# computed result for 23750 ; i =  4898
#  class is:  12
# computed result for 23752 ; i =  4899
#  class is:  9
# computed result for 23753 ; i =  4900
#  class is:  7
# computed result for 23759 ; i =  4901
#  class is:  19
# computed result for 23762 ; i =  4902
#  class is:  10
# computed result for 23765 ; i =  4903
#  class is:  13
# computed result for 23767 ; i =  4904
#  class is:  17
# computed result for 23771 ; i =  4905
#  class is:  18
# computed result for 23773 ; i =  4906
#  class is:  17
# computed result for 23774 ; i =  4907
#  class is:  2
# computed result for 23776 ; i =  4908
#  class is:  6
# computed result for 23779 ; i =  4909
#  class is:  9
# computed result for 23782 ; i =  4910
#  class is:  9
# computed result for 23783 ; i =  4911
#  class is:  14
# computed result for 23789 ; i =  4912
#  class is:  19
# computed result for 23792 ; i =  4913
#  class is:  16
# computed result for 23797 ; i =  4914
#  class is:  8
# computed result for 23809 ; i =  4915
#  class is:  14
# computed result for 23810 ; i =  4916
#  class is:  2
# computed result for 23813 ; i =  4917
#  class is:  17
# computed result for 23823 ; i =  4918
#  class is:  6
# computed result for 23825 ; i =  4919
#  class is:  16
# computed result for 23826 ; i =  4920
#  class is:  17
# computed result for 23829 ; i =  4921
#  class is:  20
# computed result for 23830 ; i =  4922
#  class is:  10
# computed result for 23831 ; i =  4923
#  class is:  5
# computed result for 23834 ; i =  4924
#  class is:  2
# computed result for 23837 ; i =  4925
#  class is:  9
# computed result for 23839 ; i =  4926
#  class is:  12
# computed result for 23840 ; i =  4927
#  class is:  17
# computed result for 23841 ; i =  4928
#  class is:  4
# computed result for 23843 ; i =  4929
#  class is:  11
# computed result for 23844 ; i =  4930
#  class is:  16
# computed result for 23846 ; i =  4931
#  class is:  3
# computed result for 23847 ; i =  4932
#  class is:  9
# computed result for 23848 ; i =  4933
#  class is:  4
# computed result for 23849 ; i =  4934
#  class is:  4
# computed result for 23851 ; i =  4935
#  class is:  13
# computed result for 23858 ; i =  4936
#  class is:  8
# computed result for 23859 ; i =  4937
#  class is:  11
# computed result for 23860 ; i =  4938
#  class is:  13
# computed result for 23864 ; i =  4939
#  class is:  16
# computed result for 23865 ; i =  4940
#  class is:  13
# computed result for 23870 ; i =  4941
#  class is:  14
# computed result for 23871 ; i =  4942
#  class is:  9
# computed result for 23875 ; i =  4943
#  class is:  9
# computed result for 23876 ; i =  4944
#  class is:  2
# computed result for 23888 ; i =  4945
#  class is:  15
# computed result for 23890 ; i =  4946
#  class is:  3
# computed result for 23891 ; i =  4947
#  class is:  3
# computed result for 23892 ; i =  4948
#  class is:  17
# computed result for 23893 ; i =  4949
#  class is:  5
# computed result for 23895 ; i =  4950
#  class is:  9
# computed result for 23898 ; i =  4951
#  class is:  6
# computed result for 23899 ; i =  4952
#  class is:  18
# computed result for 23901 ; i =  4953
#  class is:  18
# computed result for 23903 ; i =  4954
#  class is:  15
# computed result for 23906 ; i =  4955
#  class is:  9
# computed result for 23907 ; i =  4956
#  class is:  14
# computed result for 23908 ; i =  4957
#  class is:  8
# computed result for 23909 ; i =  4958
#  class is:  13
# computed result for 23911 ; i =  4959
#  class is:  15
# computed result for 23913 ; i =  4960
#  class is:  17
# computed result for 23915 ; i =  4961
#  class is:  14
# computed result for 23916 ; i =  4962
#  class is:  9
# computed result for 23917 ; i =  4963
#  class is:  4
# computed result for 23920 ; i =  4964
#  class is:  2
# computed result for 23922 ; i =  4965
#  class is:  14
# computed result for 23923 ; i =  4966
#  class is:  11
# computed result for 23924 ; i =  4967
#  class is:  19
# computed result for 23934 ; i =  4968
#  class is:  20
# computed result for 23935 ; i =  4969
#  class is:  3
# computed result for 23937 ; i =  4970
#  class is:  9
# computed result for 23938 ; i =  4971
#  class is:  9
# computed result for 23939 ; i =  4972
#  class is:  20
# computed result for 23940 ; i =  4973
#  class is:  4
# computed result for 23941 ; i =  4974
#  class is:  7
# computed result for 23944 ; i =  4975
#  class is:  20
# computed result for 23946 ; i =  4976
#  class is:  1
# computed result for 23949 ; i =  4977
#  class is:  17
# computed result for 23952 ; i =  4978
#  class is:  4
# computed result for 23954 ; i =  4979
#  class is:  1
# computed result for 23955 ; i =  4980
#  class is:  19
# computed result for 23956 ; i =  4981
#  class is:  12
# computed result for 23957 ; i =  4982
#  class is:  9
# computed result for 23960 ; i =  4983
#  class is:  4
# computed result for 23961 ; i =  4984
#  class is:  6
# computed result for 23962 ; i =  4985
#  class is:  9
# computed result for 23964 ; i =  4986
#  class is:  9
# computed result for 23966 ; i =  4987
#  class is:  7
# computed result for 23969 ; i =  4988
#  class is:  11
# computed result for 23971 ; i =  4989
#  class is:  19
# computed result for 23973 ; i =  4990
#  class is:  11
# computed result for 23976 ; i =  4991
#  class is:  4
# computed result for 23979 ; i =  4992
#  class is:  4
# computed result for 23983 ; i =  4993
#  class is:  6
# computed result for 23984 ; i =  4994
#  class is:  17
# computed result for 23986 ; i =  4995
#  class is:  3
# computed result for 23991 ; i =  4996
#  class is:  12
# computed result for 23992 ; i =  4997
#  class is:  18
# computed result for 23998 ; i =  4998
#  class is:  1
# computed result for 24000 ; i =  4999
#  class is:  1
# [[10001     3]
#  [10002     6]
#  [10004     9]
#  ...
#  [23992    18]
#  [23998     1]
#  [24000     1]]
